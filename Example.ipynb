# %%
# !python example.py
# Out:
# 25

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_68/2743823995.py in <module>
# ----> 1 print(c)
#
# NameError: name 'c' is not defined
